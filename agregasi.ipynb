# %%
class Shop:
   def __init__(self, id, name, seller):
       self.id = id
       self.name = name
       Seller.seller = seller
  
   def setSeller(self, value):
       self.seller = value
 
   def getSeller(self):
       return self.seller
 
class Seller:
   def __init__(self, id, name):
       self.id = id
       self.name = name
