# %%
class DataRepository:
  def __init__(self):
    self.data = []

  def setData(self):
    response = #  tons of logical code to retrieve data
    self.data.clear()
    self.data.insert(response.data)

  def getData(self):
    return self.data
# Out:
#   File "<ipython-input-2-3671c09f3ded>", line 6
#     response = #  tons of logical code to retrieve data
#                                                        ^
# SyntaxError: invalid syntax

# %%
#polymorphism

class App:
   def __init__(self):
       cat = Cat()
       cat.walk()
 
class Animal:
   def walk(self):
       print(self.__name__ + " walk!")
 
class Cat(Animal):
   def __init__(self):
       super().walk()
       print("Yeay! " + self.__name__ + " walk!")
