# %%
class App:
   def __init__(self):
       user = User("1234", "Khrisna", Address("123", "Bandung"))
 
class User:
   def __init__(self, id, name, address):
       self.id = id
       self.name = name
       self.address = address
 
class Address:
   def __init__(self, id, location):
       self.id = id
       self.location = location
