# %%
class ProductService:
   def getProduct(id):
       raise NotImplementedError
 
   def calculateProductPrice():
       raise NotImplementedError
 
class ProductServiceImpl(ProductService):
   def getProduct(id):
       ... # Implementation code
 
   def calculateProductPrice():
       ... # implementation code
