# %%
#urutan aritmatika
#1. tanda kurung
#2. perkalian dan pembagian --> 3/4*5
#3. penjumlahan dan pengurangan --> 3 -(4+5)

# %%
3/4*5
# Out:
# 3.75

# %%
3 -(4+5)
# Out:
# -6

# %% [markdown]
# **Menulis Formula Matematis Di Python**

# %%
from IPython.display import display, Math

# %%
display('4 + 3 = 7')
# Out:
# '4 + 3 = 7'

# %%
display(Math('4 + 3 = 7'))
# Out:
# $$4 + 3 = 7$$

# %%
x = 10
y = 5

display(Math(f'{x} + {y} = {x+y}'))
# Out:
# $$10 + 5 = 15$$

# %%
display(Math('{} + {} = {}'.format(x, y, x+y)))
# Out:
# $$10 + 5 = 15$$

# %%
# soal
x = 5
y = 10
z = 2

jawaban1 =  5*x*(5+y)
jawaban1
# Out:
# 375
